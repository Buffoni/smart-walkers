# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches
from tqdm.notebook import tqdm
from scipy.constants import Boltzmann
from itertools import accumulate

print(f'Costante di Boltzmann {Boltzmann} J/K')

NUMBER_OF_SQUARES = 4
NUMBER_OF_GAMES = int(1e4)
START_POS_ALICE = 1
START_POS_BOB = NUMBER_OF_SQUARES - 2
# Out:
# Costante di Boltzmann 1.380649e-23 J/K

# %%
# Softmax to perform Boltzmann exploration
def softmax(vector, temperature):
  exp_vector = np.exp(vector / temperature)
  return exp_vector / np.sum(exp_vector)

class Walker():
  def __init__(self, name, start_position, world_dimension, use_brain, learning_rate=0.5, discount_factor=1, softmax_temperature=1):
    self.name = name
    self.start_position = start_position
    self.position = start_position

    self.memory = {
        'my_previous_position': None,
        'my_previous_move': None,
        'other_walker_previous_position': None
    }

    self.world_dimension = world_dimension

    # Initialization as random walker
    self.q_table = np.ones((world_dimension, world_dimension, 3)) / 3

    self.learning_rate = learning_rate
    self.discount_factor = discount_factor

    self.softmax_temperature = softmax_temperature

    self.use_brain = use_brain

  def reset(self):
    self.position = self.start_position
    self.memory = {
        'my_previous_position': None,
        'my_previous_move': None,
        'other_walker_previous_position': None
    }

  def update_memory(self, my_position, other_position, my_move):
    self.memory['my_previous_position'] = my_position
    self.memory['my_previous_move'] = my_move
    self.memory['other_walker_previous_position'] = other_position

  def get_probability_tensor(self):
    probability_tensor = np.zeros((self.world_dimension, self.world_dimension, 3))
    for i in range(self.world_dimension):
      for j in range(self.world_dimension):
        probability_tensor[i, j] = softmax(self.q_table[i, j], self.softmax_temperature)
    return probability_tensor

  def choose_move(self, other_walker_position):
    if self.use_brain:
      # Policy
      probabilities = softmax(self.q_table[self.position, other_walker_position], self.softmax_temperature)
      move = np.random.choice([-1, 0, 1], p=probabilities)
    else:
      move = np.random.choice([-1, 0, 1])
    return move

  def check_if_move_is_possible(self, move):
    # Check if we end up under 0
    if self.position + move < 0:
      return False
    # Check if we end up over the world dimension
    elif self.position + move >= self.world_dimension:
      return False
    else:
      return True

  def move(self, other_position):
    move = self.choose_move(other_position)
    self.update_memory(self.position, other_position, move)
    if self.check_if_move_is_possible(move):
      self.position += move

  def update_brain(self, reward, other_position):
    if self.use_brain:
      old_q_value = self.q_table[self.memory['my_previous_position'], self.memory['other_walker_previous_position'], self.memory['my_previous_move'] + 1]
      new_q_value = reward + self.discount_factor * np.max(self.q_table[self.position, other_position])
      self.q_table[self.memory['my_previous_position'], self.memory['other_walker_previous_position'], self.memory['my_previous_move'] + 1] = \
        (1-self.learning_rate) * old_q_value + self.learning_rate * new_q_value

# %%
def check_same_position(walker_1, walker_2):
  if walker_1.position == walker_2.position:
    return True
  else:
    return False

def check_compenetration(walker_1, walker_2):
  if walker_1.memory['my_previous_position'] == walker_2.position and walker_2.memory['my_previous_position'] == walker_1.position:
    return True
  else:
    return False

def check_end_game(walker_1, walker_2):
  end_game = False
  compenetration = False
  if check_same_position(walker_1, walker_2):
    end_game = True
  elif check_compenetration(walker_1, walker_2):
    # Coin toss to choose the final position of the two walkers
    if np.random.rand() < 0.5:
      walker_1.position = walker_2.position
    else:
      walker_2.position = walker_1.position
    end_game = True
    compenetration = True
  else:
    end_game = False

  return end_game, compenetration

def calculate_reward(meeting_square, world_dimension):
  # Get the points
  walker_1_reward = world_dimension - meeting_square - world_dimension / 2
  walker_2_reward = meeting_square - world_dimension / 2
  return walker_1_reward, walker_2_reward

def play_one_game(walker_1, walker_2, world_dimension):
  # Reset the walkers
  walker_1.reset()
  walker_2.reset()
  moves = 0
  while True:
    walker_1.move(walker_2.position)
    walker_2.move(walker_1.position)
    moves += 1

    end_game, compenetration = check_end_game(walker_1, walker_2)

    if end_game:

      if walker_1.position != walker_2.position:
        raise Exception('The walkers are not in the same position at the end of the game')
      else:
        meeting_square = walker_1.position

      walker_1_reward, walker_2_reward = calculate_reward(
          meeting_square,
          world_dimension,
        )

      walker_1.update_brain(walker_1_reward, walker_2.position)
      walker_2.update_brain(walker_2_reward, walker_1.position)
      break
    else:
      walker_1.update_brain(0, walker_2.position)
      walker_2.update_brain(0, walker_1.position)

  return walker_1_reward, walker_2_reward, moves, meeting_square

# %%
# Plot walker_1 (Alice) reward

meeting_squares =  np.linspace(0, NUMBER_OF_SQUARES-1, NUMBER_OF_SQUARES)
walker_1_rewards = []
for meeting_square in meeting_squares:
  walker_1_reward, _ = calculate_reward(meeting_square, NUMBER_OF_SQUARES)
  walker_1_rewards.append(walker_1_reward)

plt.title('Reward of Walker 1 (Alice)')
plt.xlabel('Meeting square')
plt.ylabel('Reward')
plt.plot(meeting_squares, walker_1_rewards, label='Walker 1 (Alice)', color='blue')
plt.axhline(0, color='black', linestyle='--')
plt.xticks(np.arange(0, NUMBER_OF_SQUARES, 1))
plt.legend()
plt.show()

# %%
def calculate_entropy_of_probability_tensor(probability_tensor):
  entropy = 0
  for i in range(probability_tensor.shape[0]):
    for j in range(probability_tensor.shape[1]):
      for k in range(probability_tensor.shape[2]):
        entropy -= probability_tensor[i, j, k] * np.log2(probability_tensor[i, j, k])

  maximum_possible_entropy = np.log2(probability_tensor.shape[2]) * probability_tensor.shape[0] * probability_tensor.shape[1]
  negentropy = maximum_possible_entropy - entropy

  entropy = round(entropy, 10)
  negentropy = round(negentropy, 10)

  return entropy, negentropy

# %%
# This initialization is crucial: Alice uses the brain and Bob doesn't!
alice = Walker(name='Alice', start_position=START_POS_ALICE, world_dimension=NUMBER_OF_SQUARES, use_brain=True)
bob = Walker(name='Bob', start_position=START_POS_BOB, world_dimension=NUMBER_OF_SQUARES, use_brain=False)

alice_rewards = []
bob_rewards = []
meeting_squares = []
alice_entropies = []
bob_entropies = []
alice_negentropies = []
bob_negentropies = []

for i in tqdm(range(NUMBER_OF_GAMES)):
  alice_reward, bob_reward, moves, meeting_square = play_one_game(
      alice,
      bob,
      NUMBER_OF_SQUARES
    )
  alice_rewards.append(alice_reward)
  bob_rewards.append(bob_reward)
  meeting_squares.append(meeting_square)

  alice_probability_tensor = alice.get_probability_tensor()
  bob_probability_tensor = bob.get_probability_tensor()

  alice_entropy, alice_negentropy = calculate_entropy_of_probability_tensor(alice_probability_tensor)
  bob_entropy, bob_negentropy = calculate_entropy_of_probability_tensor(bob_probability_tensor)

  alice_entropies.append(alice_entropy)
  bob_entropies.append(bob_entropy)
  alice_negentropies.append(alice_negentropy)
  bob_negentropies.append(bob_negentropy)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# Plot total reward vs game number

plt.title('Total reward vs game number')
plt.plot(np.cumsum(alice_rewards), label='Alice total reward')
plt.plot(np.cumsum(bob_rewards), label='Bob total reward')
plt.xlabel('Game number')
plt.ylabel('Total reward')
plt.legend()
plt.show()

# %%
# Plot entropy and negentropy vs game number

plt.title('Entropy and negentropy vs game number')
plt.plot(alice_entropies, label='Alice entropy')
plt.plot(bob_entropies, label='Bob entropy')
plt.plot(alice_negentropies, label='Alice negentropy')
plt.plot(bob_negentropies, label='Bob negentropy')
plt.xlabel('Game number')
plt.ylabel('Entropy and negentropy')
plt.legend()
plt.show()

# %%
# Get sample random dynamic:

# Get experimental first encounter positions without brain (random walkers)

alice_random = Walker(name='Alice', start_position=0, world_dimension=NUMBER_OF_SQUARES, use_brain=False)
bob_random = Walker(name='Bob', start_position=NUMBER_OF_SQUARES-1, world_dimension=NUMBER_OF_SQUARES, use_brain=False)

random_meeting_squares = []

for i in tqdm(range(NUMBER_OF_GAMES), desc='Get random dynamic'):
  _, _, _, meeting_square = play_one_game(
      alice_random,
      bob_random,
      NUMBER_OF_SQUARES
    )
  random_meeting_squares.append(meeting_square)
# Out:
# Get random dynamic:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# Plot first encounter histograms

plt.title('First encounter histogram (simulation)')

first_encounter_positions = meeting_squares
random_first_encounter_positions = random_meeting_squares

plt.hist(first_encounter_positions, bins=NUMBER_OF_SQUARES, label='First encounter position', alpha=0.5)
plt.hist(random_first_encounter_positions, bins=NUMBER_OF_SQUARES, label='First encounter position (random walkers)', alpha=0.5)
plt.xlabel('First encounter position')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
# Build matrix A

def convert_indices_to_global(i, j, i_prime, j_prime):
    '''
    This is crucial!
    (i, j) current state: Alice at i, Bob at j
    (i', j') next state
    '''
    global_i = i_prime * NUMBER_OF_SQUARES + j_prime
    global_j = i * NUMBER_OF_SQUARES + j
    return global_i, global_j

def impose_reflective_boundary_conditions(probability_tensor):
  '''
  Transfers the probability mass from the sides to the stationary state.
  This is crucial since in the simulation the walkers are not allowed to go outside the world.
  And this limit is enforced by the environment!
  '''
  for i in range(NUMBER_OF_SQUARES):
    probability_tensor[0, i, 1] += probability_tensor[0, i, 0]
    probability_tensor[0, i, 0] = 0
    probability_tensor[NUMBER_OF_SQUARES-1, i, 1] += probability_tensor[NUMBER_OF_SQUARES-1, i, 2]
    probability_tensor[NUMBER_OF_SQUARES-1, i, 2] = 0

def build_matrix_A(walker_1_prob_tensor, walker_2_prob_tensor):

  A = np.zeros((NUMBER_OF_SQUARES**2, NUMBER_OF_SQUARES**2))

  for i in range(NUMBER_OF_SQUARES):
    for j in range(NUMBER_OF_SQUARES):
      for i_prime in range(NUMBER_OF_SQUARES):
        for j_prime in range(NUMBER_OF_SQUARES):
          
          global_i, global_j = convert_indices_to_global(i, j, i_prime, j_prime)

          if np.abs(i-i_prime) > 1 or np.abs(j-j_prime) > 1:
            A[global_i, global_j] = 0
          else:
            if i == i_prime + 1 and j == j_prime +1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 0] * walker_2_prob_tensor[i, j, 0]
            elif i == i_prime + 1 and j == j_prime:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 0] * walker_2_prob_tensor[i, j, 1]
            elif i == i_prime + 1 and j == j_prime - 1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 0] * walker_2_prob_tensor[i, j, 2]
            elif i == i_prime and j == j_prime + 1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 1] * walker_2_prob_tensor[i, j, 0]
            elif i == i_prime and j == j_prime:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 1] * walker_2_prob_tensor[i, j, 1]
            elif i == i_prime and j == j_prime - 1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 1] * walker_2_prob_tensor[i, j, 2]
            elif i == i_prime - 1 and j == j_prime + 1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 2] * walker_2_prob_tensor[i, j, 0]
            elif i == i_prime - 1 and j == j_prime:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 2] * walker_2_prob_tensor[i, j, 1]
            elif i == i_prime - 1 and j == j_prime - 1:
              A[global_i, global_j] = walker_1_prob_tensor[i, j, 2] * walker_2_prob_tensor[i, j, 2]
            else:
              raise Exception('This should not happen!')

  return A

def add_absorbent_interactions(A, number_of_sites):
  # Insert interactions by replacing the columns with index: i + (i-1)*number_of_sites -1
  # with the identity column
  # (Notice the -1, it is there because the index start from 0 and not from 1)

  trap_indices_list = [i + (i-1)*number_of_sites - 1 for i in range(1, number_of_sites+1)]

  for index in trap_indices_list:
    A[:, index] = np.eye(number_of_sites**2)[:, index]

def normlization_check(A, tolerance=1e-10):
  '''
  Check if the columns of the matrix A sum to 1.
  '''
  normalization = True

  for i in range(A.shape[1]):
    if np.sum(A[:, i]) - 1 > tolerance:
      print(f'Column {i} sums to {np.sum(A[:, i])}')
      normalization = False

  if normalization:
    print('The matrix is normalized')
  else:
    print('The matrix is NOT normalized')

def normlization_check_for_tensor(probability_tensor, tolerance=1e-10):
  '''
  Check if the last dimension of the tensor sums to 1 for each i and j.
  '''
  normalization = True

  for i in range(probability_tensor.shape[0]):
    for j in range(probability_tensor.shape[1]):
      if np.sum(probability_tensor[i, j]) - 1 > tolerance:
        print(f'Column {i} sums to {np.sum(probability_tensor[i, j])}')
        normalization = False
  if normalization:
    print('The tensor is normalized')
  else:
    print('The tensor is NOT normalized')

# %%
# Calculate matrix A for random walkers and Alice with brain

# Random walkers
alice_random_probability_tensor = alice_random.get_probability_tensor()
bob_random_probability_tensor = bob_random.get_probability_tensor()

print('Probability tensors before imposing boundary conditions:')
normlization_check_for_tensor(alice_random_probability_tensor)
normlization_check_for_tensor(bob_random_probability_tensor)

# Imposing reflective boundary conditions
impose_reflective_boundary_conditions(alice_random_probability_tensor)
impose_reflective_boundary_conditions(bob_random_probability_tensor)

print('Probability tensors after imposing boundary conditions:')
normlization_check_for_tensor(alice_random_probability_tensor)
normlization_check_for_tensor(bob_random_probability_tensor)

# Build A matrix

A_random = build_matrix_A(alice_random_probability_tensor, bob_random_probability_tensor)

# Add absorbent interactions

add_absorbent_interactions(A_random, NUMBER_OF_SQUARES)

# Make plot

plt.imshow(A_random, interpolation='nearest', cmap='binary')
plt.colorbar()
plt.title('A of random walkers')
plt.xticks([])
plt.yticks([])
plt.show()

# Check normalization
normlization_check(A_random)
# Out:
# Probability tensors before imposing boundary conditions:
# The tensor is normalized
# The tensor is normalized
# Probability tensors after imposing boundary conditions:
# The tensor is normalized
# The tensor is normalized
# The matrix is normalized

# %%
# Make the same thing but for Alice with brain and Bob without brain

alice_probability_tensor = alice.get_probability_tensor()
bob_probability_tensor = bob.get_probability_tensor()

print('Probability tensors before imposing boundary conditions:')
normlization_check_for_tensor(alice_probability_tensor)
normlization_check_for_tensor(bob_probability_tensor)

# Imposing reflective boundary conditions

impose_reflective_boundary_conditions(alice_probability_tensor)
impose_reflective_boundary_conditions(bob_probability_tensor)

print('Probability tensors after imposing boundary conditions:')
normlization_check_for_tensor(alice_probability_tensor)
normlization_check_for_tensor(bob_probability_tensor)

# Build A matrix

A = build_matrix_A(alice_probability_tensor, bob_probability_tensor)

# Add absorbent interactions

add_absorbent_interactions(A, NUMBER_OF_SQUARES)

# Make plot
plt.imshow(A, interpolation='nearest', cmap='binary')
plt.colorbar()
plt.title('A of Alice with brain and Bob without brain')
plt.xticks([])
plt.yticks([])
plt.show()

# Check normalization
normlization_check(A)
# Out:
# Probability tensors before imposing boundary conditions:
# The tensor is normalized
# The tensor is normalized
# Probability tensors after imposing boundary conditions:
# The tensor is normalized
# The tensor is normalized
# The matrix is normalized

# %%
# Get theoretical curves for both cases

def get_cursive_Pts(current_A, P0, number_of_sites, free_probability_treshhold_for_theory_calc):
    '''
    Calculate time evolution, and so the capture probability on sites (cursive P)
    '''

    trap_indices_list = [i + (i-1)*number_of_sites - 1 for i in range(1, number_of_sites+1)]

    Pt = np.matmul(current_A, P0)

    delta_iterations_for_check = 100
    iterations = 0

    while True:

        Pt = np.dot(current_A, Pt)

        Cursive_Pts = []

        for index in trap_indices_list:
            Cursive_Pts.append(Pt[index])

        # Check probability mass trapped

        trapped_prob_mass = sum(Cursive_Pts)

        if iterations % delta_iterations_for_check == 0:
            print(f'Trapped probability mass at iteration {iterations}: {trapped_prob_mass}')

        if 1 - trapped_prob_mass < free_probability_treshhold_for_theory_calc:
            break
        else:
            iterations += 1

    return Cursive_Pts

# Specifing the start distribution

P0_Alice = np.zeros(NUMBER_OF_SQUARES)
P0_Alice[START_POS_ALICE] = 1

P0_Bob = np.zeros(NUMBER_OF_SQUARES)
P0_Bob[START_POS_BOB] = 1

# General P0

P0 = np.kron(P0_Alice, P0_Bob)

# %%
# Make graph of the cursive Pts

cursive_Pts_random = get_cursive_Pts(A_random, P0, NUMBER_OF_SQUARES, 10e-6)

# Plot cursive Pts

plt.title('Cursive Pts')
plt.plot(cursive_Pts_random, label='Random walkers')
plt.xlabel('Meeting square')
plt.ylabel('Cursive P')
plt.legend()
plt.xticks(np.arange(0, NUMBER_OF_SQUARES, 1))
plt.show()
# Out:
# Trapped probability mass at iteration 0: 0.3333333333333334
# Trapped probability mass at iteration 100: 0.5474225511099933
# Trapped probability mass at iteration 200: 0.5474225511099964
# Trapped probability mass at iteration 300: 0.5474225511099964
# Trapped probability mass at iteration 400: 0.5474225511099964
# Trapped probability mass at iteration 500: 0.5474225511099964
# Trapped probability mass at iteration 600: 0.5474225511099964
# Trapped probability mass at iteration 700: 0.5474225511099964
# Trapped probability mass at iteration 800: 0.5474225511099964
# Trapped probability mass at iteration 900: 0.5474225511099964
# Trapped probability mass at iteration 1000: 0.5474225511099964
# Trapped probability mass at iteration 1100: 0.5474225511099964
# Trapped probability mass at iteration 1200: 0.5474225511099964
# Trapped probability mass at iteration 1300: 0.5474225511099964
# Trapped probability mass at iteration 1400: 0.5474225511099964
# Trapped probability mass at iteration 1500: 0.5474225511099964
# Trapped probability mass at iteration 1600: 0.5474225511099964
# Trapped probability mass at iteration 1700: 0.5474225511099964
# Trapped probability mass at iteration 1800: 0.5474225511099964
# Trapped probability mass at iteration 1900: 0.5474225511099964
# Trapped probability mass at iteration 2000: 0.5474225511099964
# Trapped probability mass at iteration 2100: 0.5474225511099964
# Trapped probability mass at iteration 2200: 0.5474225511099964
# Trapped probability mass at iteration 2300: 0.5474225511099964
# Trapped probability mass at iteration 2400: 0.5474225511099964
# Trapped probability mass at iteration 2500: 0.5474225511099964
# Trapped probability mass at iteration 2600: 0.5474225511099964
# Trapped probability mass at iteration 2700: 0.5474225511099964
# Trapped probability mass at iteration 2800: 0.5474225511099964
# Trapped probability mass at iteration 2900: 0.5474225511099964
# Trapped probability mass at iteration 3000: 0.5474225511099964
# Trapped probability mass at iteration 3100: 0.5474225511099964
# Trapped probability mass at iteration 3200: 0.5474225511099964
# Trapped probability mass at iteration 3300: 0.5474225511099964
# Trapped probability mass at iteration 3400: 0.5474225511099964
# Trapped probability mass at iteration 3500: 0.5474225511099964
# Trapped probability mass at iteration 3600: 0.5474225511099964
# Trapped probability mass at iteration 3700: 0.5474225511099964
# Trapped probability mass at iteration 3800: 0.5474225511099964
# Trapped probability mass at iteration 3900: 0.5474225511099964
# Trapped probability mass at iteration 4000: 0.5474225511099964
# Trapped probability mass at iteration 4100: 0.5474225511099964
# Trapped probability mass at iteration 4200: 0.5474225511099964
# Trapped probability mass at iteration 4300: 0.5474225511099964
# Trapped probability mass at iteration 4400: 0.5474225511099964
# Trapped probability mass at iteration 4500: 0.5474225511099964
# Trapped probability mass at iteration 4600: 0.5474225511099964
# Trapped probability mass at iteration 4700: 0.5474225511099964
# Trapped probability mass at iteration 4800: 0.5474225511099964
# Trapped probability mass at iteration 4900: 0.5474225511099964
# Trapped probability mass at iteration 5000: 0.5474225511099964
# Trapped probability mass at iteration 5100: 0.5474225511099964
# Trapped probability mass at iteration 5200: 0.5474225511099964
# Trapped probability mass at iteration 5300: 0.5474225511099964
# Trapped probability mass at iteration 5400: 0.5474225511099964
# Trapped probability mass at iteration 5500: 0.5474225511099964
# Trapped probability mass at iteration 5600: 0.5474225511099964
# Trapped probability mass at iteration 5700: 0.5474225511099964
# Trapped probability mass at iteration 5800: 0.5474225511099964
# Trapped probability mass at iteration 5900: 0.5474225511099964
# Trapped probability mass at iteration 6000: 0.5474225511099964
# Trapped probability mass at iteration 6100: 0.5474225511099964
# Trapped probability mass at iteration 6200: 0.5474225511099964
# Trapped probability mass at iteration 6300: 0.5474225511099964
# Trapped probability mass at iteration 6400: 0.5474225511099964
# Trapped probability mass at iteration 6500: 0.5474225511099964
# Trapped probability mass at iteration 6600: 0.5474225511099964
# Trapped probability mass at iteration 6700: 0.5474225511099964
# Trapped probability mass at iteration 6800: 0.5474225511099964
# Trapped probability mass at iteration 6900: 0.5474225511099964
# Trapped probability mass at iteration 7000: 0.5474225511099964
# Trapped probability mass at iteration 7100: 0.5474225511099964
# Trapped probability mass at iteration 7200: 0.5474225511099964
# Trapped probability mass at iteration 7300: 0.5474225511099964
# Trapped probability mass at iteration 7400: 0.5474225511099964
# Trapped probability mass at iteration 7500: 0.5474225511099964
# Trapped probability mass at iteration 7600: 0.5474225511099964
# Trapped probability mass at iteration 7700: 0.5474225511099964
# Trapped probability mass at iteration 7800: 0.5474225511099964
# Trapped probability mass at iteration 7900: 0.5474225511099964
# Trapped probability mass at iteration 8000: 0.5474225511099964
# Trapped probability mass at iteration 8100: 0.5474225511099964
# Trapped probability mass at iteration 8200: 0.5474225511099964
# Trapped probability mass at iteration 8300: 0.5474225511099964
# Trapped probability mass at iteration 8400: 0.5474225511099964
# Trapped probability mass at iteration 8500: 0.5474225511099964
# Trapped probability mass at iteration 8600: 0.5474225511099964
# Trapped probability mass at iteration 8700: 0.5474225511099964
# Trapped probability mass at iteration 8800: 0.5474225511099964
# Trapped probability mass at iteration 8900: 0.5474225511099964
# Trapped probability mass at iteration 9000: 0.5474225511099964
# Trapped probability mass at iteration 9100: 0.5474225511099964
# Trapped probability mass at iteration 9200: 0.5474225511099964
# Trapped probability mass at iteration 9300: 0.5474225511099964
# Trapped probability mass at iteration 9400: 0.5474225511099964
# Trapped probability mass at iteration 9500: 0.5474225511099964
# Trapped probability mass at iteration 9600: 0.5474225511099964
# Trapped probability mass at iteration 9700: 0.5474225511099964
# Trapped probability mass at iteration 9800: 0.5474225511099964
# Trapped probability mass at iteration 9900: 0.5474225511099964
# Trapped probability mass at iteration 10000: 0.5474225511099964
# Trapped probability mass at iteration 10100: 0.5474225511099964
# Trapped probability mass at iteration 10200: 0.5474225511099964
# Trapped probability mass at iteration 10300: 0.5474225511099964
# Trapped probability mass at iteration 10400: 0.5474225511099964
# Trapped probability mass at iteration 10500: 0.5474225511099964
# Trapped probability mass at iteration 10600: 0.5474225511099964
# Trapped probability mass at iteration 10700: 0.5474225511099964
# Trapped probability mass at iteration 10800: 0.5474225511099964
# Trapped probability mass at iteration 10900: 0.5474225511099964
# Trapped probability mass at iteration 11000: 0.5474225511099964
# Trapped probability mass at iteration 11100: 0.5474225511099964
# Trapped probability mass at iteration 11200: 0.5474225511099964
# Trapped probability mass at iteration 11300: 0.5474225511099964
# Trapped probability mass at iteration 11400: 0.5474225511099964
# Trapped probability mass at iteration 11500: 0.5474225511099964
# Trapped probability mass at iteration 11600: 0.5474225511099964
# Trapped probability mass at iteration 11700: 0.5474225511099964
# Trapped probability mass at iteration 11800: 0.5474225511099964
# Trapped probability mass at iteration 11900: 0.5474225511099964
# Trapped probability mass at iteration 12000: 0.5474225511099964
# Trapped probability mass at iteration 12100: 0.5474225511099964
# Trapped probability mass at iteration 12200: 0.5474225511099964
# Trapped probability mass at iteration 12300: 0.5474225511099964
# Trapped probability mass at iteration 12400: 0.5474225511099964
# Trapped probability mass at iteration 12500: 0.5474225511099964
# Trapped probability mass at iteration 12600: 0.5474225511099964
# Trapped probability mass at iteration 12700: 0.5474225511099964
# Trapped probability mass at iteration 12800: 0.5474225511099964
# Trapped probability mass at iteration 12900: 0.5474225511099964
# Trapped probability mass at iteration 13000: 0.5474225511099964
# Trapped probability mass at iteration 13100: 0.5474225511099964
# Trapped probability mass at iteration 13200: 0.5474225511099964
# Trapped probability mass at iteration 13300: 0.5474225511099964
# Trapped probability mass at iteration 13400: 0.5474225511099964
# Trapped probability mass at iteration 13500: 0.5474225511099964
# Trapped probability mass at iteration 13600: 0.5474225511099964
# Trapped probability mass at iteration 13700: 0.5474225511099964
# Trapped probability mass at iteration 13800: 0.5474225511099964
# Trapped probability mass at iteration 13900: 0.5474225511099964
# Trapped probability mass at iteration 14000: 0.5474225511099964
# Trapped probability mass at iteration 14100: 0.5474225511099964
# Trapped probability mass at iteration 14200: 0.5474225511099964
# Trapped probability mass at iteration 14300: 0.5474225511099964
# Trapped probability mass at iteration 14400: 0.5474225511099964
# Trapped probability mass at iteration 14500: 0.5474225511099964
# Trapped probability mass at iteration 14600: 0.5474225511099964
# Trapped probability mass at iteration 14700: 0.5474225511099964
# Trapped probability mass at iteration 14800: 0.5474225511099964
# Trapped probability mass at iteration 14900: 0.5474225511099964
# Trapped probability mass at iteration 15000: 0.5474225511099964
# Trapped probability mass at iteration 15100: 0.5474225511099964
# Trapped probability mass at iteration 15200: 0.5474225511099964
# Trapped probability mass at iteration 15300: 0.5474225511099964
# Trapped probability mass at iteration 15400: 0.5474225511099964
# Trapped probability mass at iteration 15500: 0.5474225511099964
# Trapped probability mass at iteration 15600: 0.5474225511099964
# Trapped probability mass at iteration 15700: 0.5474225511099964
# Trapped probability mass at iteration 15800: 0.5474225511099964
# Trapped probability mass at iteration 15900: 0.5474225511099964
# Trapped probability mass at iteration 16000: 0.5474225511099964
# Trapped probability mass at iteration 16100: 0.5474225511099964
# Trapped probability mass at iteration 16200: 0.5474225511099964
# Trapped probability mass at iteration 16300: 0.5474225511099964
# Trapped probability mass at iteration 16400: 0.5474225511099964
# Trapped probability mass at iteration 16500: 0.5474225511099964
# Trapped probability mass at iteration 16600: 0.5474225511099964
# Trapped probability mass at iteration 16700: 0.5474225511099964
# Trapped probability mass at iteration 16800: 0.5474225511099964
# Trapped probability mass at iteration 16900: 0.5474225511099964
# Trapped probability mass at iteration 17000: 0.5474225511099964
# Trapped probability mass at iteration 17100: 0.5474225511099964
# Trapped probability mass at iteration 17200: 0.5474225511099964
# Trapped probability mass at iteration 17300: 0.5474225511099964
# Trapped probability mass at iteration 17400: 0.5474225511099964
# Trapped probability mass at iteration 17500: 0.5474225511099964
# Trapped probability mass at iteration 17600: 0.5474225511099964
# Trapped probability mass at iteration 17700: 0.5474225511099964
# Trapped probability mass at iteration 17800: 0.5474225511099964
# Trapped probability mass at iteration 17900: 0.5474225511099964
# Trapped probability mass at iteration 18000: 0.5474225511099964
# Trapped probability mass at iteration 18100: 0.5474225511099964
# Trapped probability mass at iteration 18200: 0.5474225511099964
# Trapped probability mass at iteration 18300: 0.5474225511099964
# Trapped probability mass at iteration 18400: 0.5474225511099964
# Trapped probability mass at iteration 18500: 0.5474225511099964
# Trapped probability mass at iteration 18600: 0.5474225511099964
# Trapped probability mass at iteration 18700: 0.5474225511099964
# Trapped probability mass at iteration 18800: 0.5474225511099964
# Trapped probability mass at iteration 18900: 0.5474225511099964
# Trapped probability mass at iteration 19000: 0.5474225511099964
# Trapped probability mass at iteration 19100: 0.5474225511099964
# Trapped probability mass at iteration 19200: 0.5474225511099964
# Trapped probability mass at iteration 19300: 0.5474225511099964
# Trapped probability mass at iteration 19400: 0.5474225511099964
# Trapped probability mass at iteration 19500: 0.5474225511099964
# Trapped probability mass at iteration 19600: 0.5474225511099964
# Trapped probability mass at iteration 19700: 0.5474225511099964
# Trapped probability mass at iteration 19800: 0.5474225511099964
# Trapped probability mass at iteration 19900: 0.5474225511099964
# Trapped probability mass at iteration 20000: 0.5474225511099964
# Trapped probability mass at iteration 20100: 0.5474225511099964
# Trapped probability mass at iteration 20200: 0.5474225511099964
# Trapped probability mass at iteration 20300: 0.5474225511099964
# Trapped probability mass at iteration 20400: 0.5474225511099964
# Trapped probability mass at iteration 20500: 0.5474225511099964
# Trapped probability mass at iteration 20600: 0.5474225511099964
# Trapped probability mass at iteration 20700: 0.5474225511099964
# Trapped probability mass at iteration 20800: 0.5474225511099964
# Trapped probability mass at iteration 20900: 0.5474225511099964
# Trapped probability mass at iteration 21000: 0.5474225511099964
# Trapped probability mass at iteration 21100: 0.5474225511099964
# Trapped probability mass at iteration 21200: 0.5474225511099964
# Trapped probability mass at iteration 21300: 0.5474225511099964
# Trapped probability mass at iteration 21400: 0.5474225511099964
# Trapped probability mass at iteration 21500: 0.5474225511099964
# Trapped probability mass at iteration 21600: 0.5474225511099964
# Trapped probability mass at iteration 21700: 0.5474225511099964
# Trapped probability mass at iteration 21800: 0.5474225511099964
# Trapped probability mass at iteration 21900: 0.5474225511099964
# Trapped probability mass at iteration 22000: 0.5474225511099964
# Trapped probability mass at iteration 22100: 0.5474225511099964
# Trapped probability mass at iteration 22200: 0.5474225511099964
# Trapped probability mass at iteration 22300: 0.5474225511099964
# Trapped probability mass at iteration 22400: 0.5474225511099964
# Trapped probability mass at iteration 22500: 0.5474225511099964
# Trapped probability mass at iteration 22600: 0.5474225511099964
# Trapped probability mass at iteration 22700: 0.5474225511099964
# Trapped probability mass at iteration 22800: 0.5474225511099964
# Trapped probability mass at iteration 22900: 0.5474225511099964
# Trapped probability mass at iteration 23000: 0.5474225511099964
# Trapped probability mass at iteration 23100: 0.5474225511099964
# Trapped probability mass at iteration 23200: 0.5474225511099964
# Trapped probability mass at iteration 23300: 0.5474225511099964
# Trapped probability mass at iteration 23400: 0.5474225511099964
# Trapped probability mass at iteration 23500: 0.5474225511099964
# Trapped probability mass at iteration 23600: 0.5474225511099964
# Trapped probability mass at iteration 23700: 0.5474225511099964
# Trapped probability mass at iteration 23800: 0.5474225511099964
# Trapped probability mass at iteration 23900: 0.5474225511099964
# Trapped probability mass at iteration 24000: 0.5474225511099964
# Trapped probability mass at iteration 24100: 0.5474225511099964
# Trapped probability mass at iteration 24200: 0.5474225511099964
# Trapped probability mass at iteration 24300: 0.5474225511099964
# Trapped probability mass at iteration 24400: 0.5474225511099964
# Trapped probability mass at iteration 24500: 0.5474225511099964
# Trapped probability mass at iteration 24600: 0.5474225511099964
# Trapped probability mass at iteration 24700: 0.5474225511099964
# Trapped probability mass at iteration 24800: 0.5474225511099964
# Trapped probability mass at iteration 24900: 0.5474225511099964
# Trapped probability mass at iteration 25000: 0.5474225511099964
# Trapped probability mass at iteration 25100: 0.5474225511099964
# Trapped probability mass at iteration 25200: 0.5474225511099964
# Trapped probability mass at iteration 25300: 0.5474225511099964
# Trapped probability mass at iteration 25400: 0.5474225511099964
# Trapped probability mass at iteration 25500: 0.5474225511099964
# Trapped probability mass at iteration 25600: 0.5474225511099964
# Trapped probability mass at iteration 25700: 0.5474225511099964
# Trapped probability mass at iteration 25800: 0.5474225511099964
# Trapped probability mass at iteration 25900: 0.5474225511099964
# Trapped probability mass at iteration 26000: 0.5474225511099964
# Trapped probability mass at iteration 26100: 0.5474225511099964
# Trapped probability mass at iteration 26200: 0.5474225511099964
# Trapped probability mass at iteration 26300: 0.5474225511099964
# Trapped probability mass at iteration 26400: 0.5474225511099964
# Trapped probability mass at iteration 26500: 0.5474225511099964
# Trapped probability mass at iteration 26600: 0.5474225511099964
# Trapped probability mass at iteration 26700: 0.5474225511099964
# Trapped probability mass at iteration 26800: 0.5474225511099964
# Trapped probability mass at iteration 26900: 0.5474225511099964
# Trapped probability mass at iteration 27000: 0.5474225511099964
# Trapped probability mass at iteration 27100: 0.5474225511099964
# Trapped probability mass at iteration 27200: 0.5474225511099964
# Trapped probability mass at iteration 27300: 0.5474225511099964
# Trapped probability mass at iteration 27400: 0.5474225511099964
# Trapped probability mass at iteration 27500: 0.5474225511099964
# Trapped probability mass at iteration 27600: 0.5474225511099964
# Trapped probability mass at iteration 27700: 0.5474225511099964
# Trapped probability mass at iteration 27800: 0.5474225511099964
# Trapped probability mass at iteration 27900: 0.5474225511099964
# Trapped probability mass at iteration 28000: 0.5474225511099964
# Trapped probability mass at iteration 28100: 0.5474225511099964
# Trapped probability mass at iteration 28200: 0.5474225511099964
# Trapped probability mass at iteration 28300: 0.5474225511099964
# Trapped probability mass at iteration 28400: 0.5474225511099964
# Trapped probability mass at iteration 28500: 0.5474225511099964
# Trapped probability mass at iteration 28600: 0.5474225511099964
# Trapped probability mass at iteration 28700: 0.5474225511099964
# Trapped probability mass at iteration 28800: 0.5474225511099964
# Trapped probability mass at iteration 28900: 0.5474225511099964
# Trapped probability mass at iteration 29000: 0.5474225511099964
# Trapped probability mass at iteration 29100: 0.5474225511099964
# Trapped probability mass at iteration 29200: 0.5474225511099964
# Trapped probability mass at iteration 29300: 0.5474225511099964
# Trapped probability mass at iteration 29400: 0.5474225511099964
# Trapped probability mass at iteration 29500: 0.5474225511099964
# Trapped probability mass at iteration 29600: 0.5474225511099964
# Trapped probability mass at iteration 29700: 0.5474225511099964
# Trapped probability mass at iteration 29800: 0.5474225511099964
# Trapped probability mass at iteration 29900: 0.5474225511099964
# Trapped probability mass at iteration 30000: 0.5474225511099964
# Trapped probability mass at iteration 30100: 0.5474225511099964
# Trapped probability mass at iteration 30200: 0.5474225511099964
# Trapped probability mass at iteration 30300: 0.5474225511099964
# Trapped probability mass at iteration 30400: 0.5474225511099964
# Trapped probability mass at iteration 30500: 0.5474225511099964
# Trapped probability mass at iteration 30600: 0.5474225511099964
# Trapped probability mass at iteration 30700: 0.5474225511099964
# Trapped probability mass at iteration 30800: 0.5474225511099964
# Trapped probability mass at iteration 30900: 0.5474225511099964
# Trapped probability mass at iteration 31000: 0.5474225511099964
# Trapped probability mass at iteration 31100: 0.5474225511099964
# Trapped probability mass at iteration 31200: 0.5474225511099964
# Trapped probability mass at iteration 31300: 0.5474225511099964
# Trapped probability mass at iteration 31400: 0.5474225511099964
# Trapped probability mass at iteration 31500: 0.5474225511099964
# Trapped probability mass at iteration 31600: 0.5474225511099964
# Trapped probability mass at iteration 31700: 0.5474225511099964
# Trapped probability mass at iteration 31800: 0.5474225511099964
# Trapped probability mass at iteration 31900: 0.5474225511099964
# Trapped probability mass at iteration 32000: 0.5474225511099964
# Trapped probability mass at iteration 32100: 0.5474225511099964
# Trapped probability mass at iteration 32200: 0.5474225511099964
# Trapped probability mass at iteration 32300: 0.5474225511099964
# Trapped probability mass at iteration 32400: 0.5474225511099964
# Trapped probability mass at iteration 32500: 0.5474225511099964
# Trapped probability mass at iteration 32600: 0.5474225511099964
# Trapped probability mass at iteration 32700: 0.5474225511099964
# Trapped probability mass at iteration 32800: 0.5474225511099964
# Trapped probability mass at iteration 32900: 0.5474225511099964
# Trapped probability mass at iteration 33000: 0.5474225511099964
# Trapped probability mass at iteration 33100: 0.5474225511099964
# Trapped probability mass at iteration 33200: 0.5474225511099964
# Trapped probability mass at iteration 33300: 0.5474225511099964
# Trapped probability mass at iteration 33400: 0.5474225511099964
# Trapped probability mass at iteration 33500: 0.5474225511099964
# Trapped probability mass at iteration 33600: 0.5474225511099964
# Trapped probability mass at iteration 33700: 0.5474225511099964
# Trapped probability mass at iteration 33800: 0.5474225511099964
# Trapped probability mass at iteration 33900: 0.5474225511099964
# Trapped probability mass at iteration 34000: 0.5474225511099964
# Trapped probability mass at iteration 34100: 0.5474225511099964
# Trapped probability mass at iteration 34200: 0.5474225511099964
# Trapped probability mass at iteration 34300: 0.5474225511099964
# Trapped probability mass at iteration 34400: 0.5474225511099964
# Trapped probability mass at iteration 34500: 0.5474225511099964
# Trapped probability mass at iteration 34600: 0.5474225511099964
# Trapped probability mass at iteration 34700: 0.5474225511099964
# Trapped probability mass at iteration 34800: 0.5474225511099964
# Trapped probability mass at iteration 34900: 0.5474225511099964
# Trapped probability mass at iteration 35000: 0.5474225511099964
# Trapped probability mass at iteration 35100: 0.5474225511099964
# Trapped probability mass at iteration 35200: 0.5474225511099964
# Trapped probability mass at iteration 35300: 0.5474225511099964
# Trapped probability mass at iteration 35400: 0.5474225511099964
# Trapped probability mass at iteration 35500: 0.5474225511099964
# Trapped probability mass at iteration 35600: 0.5474225511099964
# Trapped probability mass at iteration 35700: 0.5474225511099964
# Trapped probability mass at iteration 35800: 0.5474225511099964
# Trapped probability mass at iteration 35900: 0.5474225511099964
# Trapped probability mass at iteration 36000: 0.5474225511099964
# Trapped probability mass at iteration 36100: 0.5474225511099964
# Trapped probability mass at iteration 36200: 0.5474225511099964
# Trapped probability mass at iteration 36300: 0.5474225511099964
# Trapped probability mass at iteration 36400: 0.5474225511099964
# Trapped probability mass at iteration 36500: 0.5474225511099964
# Trapped probability mass at iteration 36600: 0.5474225511099964
# Trapped probability mass at iteration 36700: 0.5474225511099964
# Trapped probability mass at iteration 36800: 0.5474225511099964
# Trapped probability mass at iteration 36900: 0.5474225511099964
# Trapped probability mass at iteration 37000: 0.5474225511099964
# Trapped probability mass at iteration 37100: 0.5474225511099964
# Trapped probability mass at iteration 37200: 0.5474225511099964
# Trapped probability mass at iteration 37300: 0.5474225511099964
# Trapped probability mass at iteration 37400: 0.5474225511099964
# Trapped probability mass at iteration 37500: 0.5474225511099964
# Trapped probability mass at iteration 37600: 0.5474225511099964
# Trapped probability mass at iteration 37700: 0.5474225511099964
# Trapped probability mass at iteration 37800: 0.5474225511099964
# Trapped probability mass at iteration 37900: 0.5474225511099964
# Trapped probability mass at iteration 38000: 0.5474225511099964
# Trapped probability mass at iteration 38100: 0.5474225511099964
# Trapped probability mass at iteration 38200: 0.5474225511099964
# Trapped probability mass at iteration 38300: 0.5474225511099964
# Trapped probability mass at iteration 38400: 0.5474225511099964
# Trapped probability mass at iteration 38500: 0.5474225511099964
# Trapped probability mass at iteration 38600: 0.5474225511099964
# Trapped probability mass at iteration 38700: 0.5474225511099964
# Trapped probability mass at iteration 38800: 0.5474225511099964
# Trapped probability mass at iteration 38900: 0.5474225511099964
# Trapped probability mass at iteration 39000: 0.5474225511099964
# Trapped probability mass at iteration 39100: 0.5474225511099964
# Trapped probability mass at iteration 39200: 0.5474225511099964
# Trapped probability mass at iteration 39300: 0.5474225511099964
# Trapped probability mass at iteration 39400: 0.5474225511099964
# Trapped probability mass at iteration 39500: 0.5474225511099964
# Trapped probability mass at iteration 39600: 0.5474225511099964
# Trapped probability mass at iteration 39700: 0.5474225511099964
# Trapped probability mass at iteration 39800: 0.5474225511099964
# Trapped probability mass at iteration 39900: 0.5474225511099964
# Trapped probability mass at iteration 40000: 0.5474225511099964
# Trapped probability mass at iteration 40100: 0.5474225511099964
# Trapped probability mass at iteration 40200: 0.5474225511099964
# Trapped probability mass at iteration 40300: 0.5474225511099964
# Trapped probability mass at iteration 40400: 0.5474225511099964
# Trapped probability mass at iteration 40500: 0.5474225511099964
# Trapped probability mass at iteration 40600: 0.5474225511099964
# Trapped probability mass at iteration 40700: 0.5474225511099964
# Trapped probability mass at iteration 40800: 0.5474225511099964
# Trapped probability mass at iteration 40900: 0.5474225511099964
# Trapped probability mass at iteration 41000: 0.5474225511099964
# Trapped probability mass at iteration 41100: 0.5474225511099964
# Trapped probability mass at iteration 41200: 0.5474225511099964
# Trapped probability mass at iteration 41300: 0.5474225511099964
# Trapped probability mass at iteration 41400: 0.5474225511099964
# Trapped probability mass at iteration 41500: 0.5474225511099964
# Trapped probability mass at iteration 41600: 0.5474225511099964
# Trapped probability mass at iteration 41700: 0.5474225511099964
# Trapped probability mass at iteration 41800: 0.5474225511099964
# Trapped probability mass at iteration 41900: 0.5474225511099964
# Trapped probability mass at iteration 42000: 0.5474225511099964
# Trapped probability mass at iteration 42100: 0.5474225511099964
# Trapped probability mass at iteration 42200: 0.5474225511099964
# Trapped probability mass at iteration 42300: 0.5474225511099964
# Trapped probability mass at iteration 42400: 0.5474225511099964
# Trapped probability mass at iteration 42500: 0.5474225511099964
# Trapped probability mass at iteration 42600: 0.5474225511099964
# Trapped probability mass at iteration 42700: 0.5474225511099964
# Trapped probability mass at iteration 42800: 0.5474225511099964
# Trapped probability mass at iteration 42900: 0.5474225511099964
# Trapped probability mass at iteration 43000: 0.5474225511099964
# Trapped probability mass at iteration 43100: 0.5474225511099964
# Trapped probability mass at iteration 43200: 0.5474225511099964
# Trapped probability mass at iteration 43300: 0.5474225511099964
# Trapped probability mass at iteration 43400: 0.5474225511099964
# Trapped probability mass at iteration 43500: 0.5474225511099964
# Trapped probability mass at iteration 43600: 0.5474225511099964
# Trapped probability mass at iteration 43700: 0.5474225511099964
# Trapped probability mass at iteration 43800: 0.5474225511099964
# Trapped probability mass at iteration 43900: 0.5474225511099964
# Trapped probability mass at iteration 44000: 0.5474225511099964
# Trapped probability mass at iteration 44100: 0.5474225511099964
# Trapped probability mass at iteration 44200: 0.5474225511099964
# Trapped probability mass at iteration 44300: 0.5474225511099964
# Trapped probability mass at iteration 44400: 0.5474225511099964
# Trapped probability mass at iteration 44500: 0.5474225511099964
# Trapped probability mass at iteration 44600: 0.5474225511099964
# Trapped probability mass at iteration 44700: 0.5474225511099964
# Trapped probability mass at iteration 44800: 0.5474225511099964
# Trapped probability mass at iteration 44900: 0.5474225511099964
# Trapped probability mass at iteration 45000: 0.5474225511099964
# Trapped probability mass at iteration 45100: 0.5474225511099964
# Trapped probability mass at iteration 45200: 0.5474225511099964
# Trapped probability mass at iteration 45300: 0.5474225511099964
# Trapped probability mass at iteration 45400: 0.5474225511099964
# Trapped probability mass at iteration 45500: 0.5474225511099964
# Trapped probability mass at iteration 45600: 0.5474225511099964
# Trapped probability mass at iteration 45700: 0.5474225511099964
# Trapped probability mass at iteration 45800: 0.5474225511099964
# Trapped probability mass at iteration 45900: 0.5474225511099964
# Trapped probability mass at iteration 46000: 0.5474225511099964
# Trapped probability mass at iteration 46100: 0.5474225511099964
# Trapped probability mass at iteration 46200: 0.5474225511099964
# Trapped probability mass at iteration 46300: 0.5474225511099964
# Trapped probability mass at iteration 46400: 0.5474225511099964
# Trapped probability mass at iteration 46500: 0.5474225511099964
# Trapped probability mass at iteration 46600: 0.5474225511099964
# Trapped probability mass at iteration 46700: 0.5474225511099964
# Trapped probability mass at iteration 46800: 0.5474225511099964
# Trapped probability mass at iteration 46900: 0.5474225511099964
# Trapped probability mass at iteration 47000: 0.5474225511099964
# Trapped probability mass at iteration 47100: 0.5474225511099964
# Trapped probability mass at iteration 47200: 0.5474225511099964
# Trapped probability mass at iteration 47300: 0.5474225511099964
# Trapped probability mass at iteration 47400: 0.5474225511099964
# Trapped probability mass at iteration 47500: 0.5474225511099964
# Trapped probability mass at iteration 47600: 0.5474225511099964
# Trapped probability mass at iteration 47700: 0.5474225511099964
# Trapped probability mass at iteration 47800: 0.5474225511099964
# Trapped probability mass at iteration 47900: 0.5474225511099964
# Trapped probability mass at iteration 48000: 0.5474225511099964
# Trapped probability mass at iteration 48100: 0.5474225511099964
# Trapped probability mass at iteration 48200: 0.5474225511099964
# Trapped probability mass at iteration 48300: 0.5474225511099964
# Trapped probability mass at iteration 48400: 0.5474225511099964
# Trapped probability mass at iteration 48500: 0.5474225511099964
# Trapped probability mass at iteration 48600: 0.5474225511099964
# Trapped probability mass at iteration 48700: 0.5474225511099964
# Trapped probability mass at iteration 48800: 0.5474225511099964
# Trapped probability mass at iteration 48900: 0.5474225511099964
# Trapped probability mass at iteration 49000: 0.5474225511099964
# Trapped probability mass at iteration 49100: 0.5474225511099964
# Trapped probability mass at iteration 49200: 0.5474225511099964
# Trapped probability mass at iteration 49300: 0.5474225511099964
# Trapped probability mass at iteration 49400: 0.5474225511099964
# Trapped probability mass at iteration 49500: 0.5474225511099964
# Trapped probability mass at iteration 49600: 0.5474225511099964
# Trapped probability mass at iteration 49700: 0.5474225511099964
# Trapped probability mass at iteration 49800: 0.5474225511099964
# Trapped probability mass at iteration 49900: 0.5474225511099964
# Trapped probability mass at iteration 50000: 0.5474225511099964
# Trapped probability mass at iteration 50100: 0.5474225511099964
# Trapped probability mass at iteration 50200: 0.5474225511099964
# Trapped probability mass at iteration 50300: 0.5474225511099964
# Trapped probability mass at iteration 50400: 0.5474225511099964
# Trapped probability mass at iteration 50500: 0.5474225511099964
# Trapped probability mass at iteration 50600: 0.5474225511099964
# Trapped probability mass at iteration 50700: 0.5474225511099964
# Trapped probability mass at iteration 50800: 0.5474225511099964
# Trapped probability mass at iteration 50900: 0.5474225511099964
# Trapped probability mass at iteration 51000: 0.5474225511099964
# Trapped probability mass at iteration 51100: 0.5474225511099964
# Trapped probability mass at iteration 51200: 0.5474225511099964
# Trapped probability mass at iteration 51300: 0.5474225511099964
# Trapped probability mass at iteration 51400: 0.5474225511099964
# Trapped probability mass at iteration 51500: 0.5474225511099964
# Trapped probability mass at iteration 51600: 0.5474225511099964
# Trapped probability mass at iteration 51700: 0.5474225511099964
# Trapped probability mass at iteration 51800: 0.5474225511099964
# Trapped probability mass at iteration 51900: 0.5474225511099964
# Trapped probability mass at iteration 52000: 0.5474225511099964
# Trapped probability mass at iteration 52100: 0.5474225511099964
# Trapped probability mass at iteration 52200: 0.5474225511099964
# Trapped probability mass at iteration 52300: 0.5474225511099964
# Trapped probability mass at iteration 52400: 0.5474225511099964
# Trapped probability mass at iteration 52500: 0.5474225511099964
# Trapped probability mass at iteration 52600: 0.5474225511099964
# Trapped probability mass at iteration 52700: 0.5474225511099964
# Trapped probability mass at iteration 52800: 0.5474225511099964
# Trapped probability mass at iteration 52900: 0.5474225511099964
# Trapped probability mass at iteration 53000: 0.5474225511099964
# Trapped probability mass at iteration 53100: 0.5474225511099964
# Trapped probability mass at iteration 53200: 0.5474225511099964
# Trapped probability mass at iteration 53300: 0.5474225511099964
# Trapped probability mass at iteration 53400: 0.5474225511099964
# Trapped probability mass at iteration 53500: 0.5474225511099964
# Trapped probability mass at iteration 53600: 0.5474225511099964
# Trapped probability mass at iteration 53700: 0.5474225511099964
# Trapped probability mass at iteration 53800: 0.5474225511099964
# Trapped probability mass at iteration 53900: 0.5474225511099964
# Trapped probability mass at iteration 54000: 0.5474225511099964
# Trapped probability mass at iteration 54100: 0.5474225511099964
# Trapped probability mass at iteration 54200: 0.5474225511099964
# Trapped probability mass at iteration 54300: 0.5474225511099964
# Trapped probability mass at iteration 54400: 0.5474225511099964
# Trapped probability mass at iteration 54500: 0.5474225511099964
# Trapped probability mass at iteration 54600: 0.5474225511099964
# Trapped probability mass at iteration 54700: 0.5474225511099964
# Trapped probability mass at iteration 54800: 0.5474225511099964
# Trapped probability mass at iteration 54900: 0.5474225511099964
# Trapped probability mass at iteration 55000: 0.5474225511099964
# Trapped probability mass at iteration 55100: 0.5474225511099964
# Trapped probability mass at iteration 55200: 0.5474225511099964
# Trapped probability mass at iteration 55300: 0.5474225511099964
# Trapped probability mass at iteration 55400: 0.5474225511099964
# Trapped probability mass at iteration 55500: 0.5474225511099964
# Trapped probability mass at iteration 55600: 0.5474225511099964
# Trapped probability mass at iteration 55700: 0.5474225511099964
# Trapped probability mass at iteration 55800: 0.5474225511099964
# Trapped probability mass at iteration 55900: 0.5474225511099964
# Trapped probability mass at iteration 56000: 0.5474225511099964
# Trapped probability mass at iteration 56100: 0.5474225511099964
# Trapped probability mass at iteration 56200: 0.5474225511099964
# Trapped probability mass at iteration 56300: 0.5474225511099964
# Trapped probability mass at iteration 56400: 0.5474225511099964
# Trapped probability mass at iteration 56500: 0.5474225511099964
# Trapped probability mass at iteration 56600: 0.5474225511099964
# Trapped probability mass at iteration 56700: 0.5474225511099964
# Trapped probability mass at iteration 56800: 0.5474225511099964
# Trapped probability mass at iteration 56900: 0.5474225511099964
# Trapped probability mass at iteration 57000: 0.5474225511099964
# Trapped probability mass at iteration 57100: 0.5474225511099964
# Trapped probability mass at iteration 57200: 0.5474225511099964
# Trapped probability mass at iteration 57300: 0.5474225511099964
# Trapped probability mass at iteration 57400: 0.5474225511099964
# Trapped probability mass at iteration 57500: 0.5474225511099964
# Trapped probability mass at iteration 57600: 0.5474225511099964
# Trapped probability mass at iteration 57700: 0.5474225511099964
# Trapped probability mass at iteration 57800: 0.5474225511099964
# Trapped probability mass at iteration 57900: 0.5474225511099964
# Trapped probability mass at iteration 58000: 0.5474225511099964
# Trapped probability mass at iteration 58100: 0.5474225511099964
# Trapped probability mass at iteration 58200: 0.5474225511099964
# Trapped probability mass at iteration 58300: 0.5474225511099964
# Trapped probability mass at iteration 58400: 0.5474225511099964
# Trapped probability mass at iteration 58500: 0.5474225511099964
# Trapped probability mass at iteration 58600: 0.5474225511099964
# Trapped probability mass at iteration 58700: 0.5474225511099964
# Trapped probability mass at iteration 58800: 0.5474225511099964
# Trapped probability mass at iteration 58900: 0.5474225511099964
# Trapped probability mass at iteration 59000: 0.5474225511099964
# Trapped probability mass at iteration 59100: 0.5474225511099964
# Trapped probability mass at iteration 59200: 0.5474225511099964
# Trapped probability mass at iteration 59300: 0.5474225511099964
# Trapped probability mass at iteration 59400: 0.5474225511099964
# Trapped probability mass at iteration 59500: 0.5474225511099964
# Trapped probability mass at iteration 59600: 0.5474225511099964
# Trapped probability mass at iteration 59700: 0.5474225511099964
# Trapped probability mass at iteration 59800: 0.5474225511099964
# Trapped probability mass at iteration 59900: 0.5474225511099964
# Trapped probability mass at iteration 60000: 0.5474225511099964
# Trapped probability mass at iteration 60100: 0.5474225511099964
# Trapped probability mass at iteration 60200: 0.5474225511099964
# Trapped probability mass at iteration 60300: 0.5474225511099964
# Trapped probability mass at iteration 60400: 0.5474225511099964
# Trapped probability mass at iteration 60500: 0.5474225511099964
# Trapped probability mass at iteration 60600: 0.5474225511099964
# Trapped probability mass at iteration 60700: 0.5474225511099964
# Trapped probability mass at iteration 60800: 0.5474225511099964
# Trapped probability mass at iteration 60900: 0.5474225511099964
# Trapped probability mass at iteration 61000: 0.5474225511099964
# Trapped probability mass at iteration 61100: 0.5474225511099964
# Trapped probability mass at iteration 61200: 0.5474225511099964
# Trapped probability mass at iteration 61300: 0.5474225511099964
# Trapped probability mass at iteration 61400: 0.5474225511099964
# Trapped probability mass at iteration 61500: 0.5474225511099964
# Trapped probability mass at iteration 61600: 0.5474225511099964
# Trapped probability mass at iteration 61700: 0.5474225511099964
# Trapped probability mass at iteration 61800: 0.5474225511099964
# Trapped probability mass at iteration 61900: 0.5474225511099964
# Trapped probability mass at iteration 62000: 0.5474225511099964
# Trapped probability mass at iteration 62100: 0.5474225511099964
# Trapped probability mass at iteration 62200: 0.5474225511099964
# Trapped probability mass at iteration 62300: 0.5474225511099964
# Trapped probability mass at iteration 62400: 0.5474225511099964
# Trapped probability mass at iteration 62500: 0.5474225511099964
# Trapped probability mass at iteration 62600: 0.5474225511099964
# Trapped probability mass at iteration 62700: 0.5474225511099964
# Trapped probability mass at iteration 62800: 0.5474225511099964
# Trapped probability mass at iteration 62900: 0.5474225511099964
# Trapped probability mass at iteration 63000: 0.5474225511099964
# Trapped probability mass at iteration 63100: 0.5474225511099964
# Trapped probability mass at iteration 63200: 0.5474225511099964
# Trapped probability mass at iteration 63300: 0.5474225511099964
# Trapped probability mass at iteration 63400: 0.5474225511099964
# Trapped probability mass at iteration 63500: 0.5474225511099964
# Trapped probability mass at iteration 63600: 0.5474225511099964
# Trapped probability mass at iteration 63700: 0.5474225511099964
# Trapped probability mass at iteration 63800: 0.5474225511099964
# Trapped probability mass at iteration 63900: 0.5474225511099964
# Trapped probability mass at iteration 64000: 0.5474225511099964
# Trapped probability mass at iteration 64100: 0.5474225511099964
# Trapped probability mass at iteration 64200: 0.5474225511099964
# Trapped probability mass at iteration 64300: 0.5474225511099964
# Trapped probability mass at iteration 64400: 0.5474225511099964
# Trapped probability mass at iteration 64500: 0.5474225511099964
# Trapped probability mass at iteration 64600: 0.5474225511099964
# Trapped probability mass at iteration 64700: 0.5474225511099964
# Trapped probability mass at iteration 64800: 0.5474225511099964
# Trapped probability mass at iteration 64900: 0.5474225511099964
# Trapped probability mass at iteration 65000: 0.5474225511099964
# Trapped probability mass at iteration 65100: 0.5474225511099964
# Trapped probability mass at iteration 65200: 0.5474225511099964
# Trapped probability mass at iteration 65300: 0.5474225511099964
# Trapped probability mass at iteration 65400: 0.5474225511099964
# Trapped probability mass at iteration 65500: 0.5474225511099964
# Trapped probability mass at iteration 65600: 0.5474225511099964
# Trapped probability mass at iteration 65700: 0.5474225511099964
# Trapped probability mass at iteration 65800: 0.5474225511099964
# Trapped probability mass at iteration 65900: 0.5474225511099964
# Trapped probability mass at iteration 66000: 0.5474225511099964
# Trapped probability mass at iteration 66100: 0.5474225511099964
# Trapped probability mass at iteration 66200: 0.5474225511099964
# Trapped probability mass at iteration 66300: 0.5474225511099964
# Trapped probability mass at iteration 66400: 0.5474225511099964
# Trapped probability mass at iteration 66500: 0.5474225511099964
# Trapped probability mass at iteration 66600: 0.5474225511099964
# Trapped probability mass at iteration 66700: 0.5474225511099964
# Trapped probability mass at iteration 66800: 0.5474225511099964
# Trapped probability mass at iteration 66900: 0.5474225511099964
# Trapped probability mass at iteration 67000: 0.5474225511099964
# Trapped probability mass at iteration 67100: 0.5474225511099964
# Trapped probability mass at iteration 67200: 0.5474225511099964
# Trapped probability mass at iteration 67300: 0.5474225511099964
# Trapped probability mass at iteration 67400: 0.5474225511099964
# Trapped probability mass at iteration 67500: 0.5474225511099964
# Trapped probability mass at iteration 67600: 0.5474225511099964
# Trapped probability mass at iteration 67700: 0.5474225511099964
# Trapped probability mass at iteration 67800: 0.5474225511099964
# Trapped probability mass at iteration 67900: 0.5474225511099964
# Trapped probability mass at iteration 68000: 0.5474225511099964
# Trapped probability mass at iteration 68100: 0.5474225511099964
# Trapped probability mass at iteration 68200: 0.5474225511099964
# Trapped probability mass at iteration 68300: 0.5474225511099964
# Trapped probability mass at iteration 68400: 0.5474225511099964
# Trapped probability mass at iteration 68500: 0.5474225511099964
# Trapped probability mass at iteration 68600: 0.5474225511099964
# Trapped probability mass at iteration 68700: 0.5474225511099964
# Trapped probability mass at iteration 68800: 0.5474225511099964
# Trapped probability mass at iteration 68900: 0.5474225511099964
# Trapped probability mass at iteration 69000: 0.5474225511099964
# Trapped probability mass at iteration 69100: 0.5474225511099964
# Trapped probability mass at iteration 69200: 0.5474225511099964
# Trapped probability mass at iteration 69300: 0.5474225511099964
# Trapped probability mass at iteration 69400: 0.5474225511099964
# Trapped probability mass at iteration 69500: 0.5474225511099964
# Trapped probability mass at iteration 69600: 0.5474225511099964
# Trapped probability mass at iteration 69700: 0.5474225511099964
# Trapped probability mass at iteration 69800: 0.5474225511099964
# Trapped probability mass at iteration 69900: 0.5474225511099964
# Trapped probability mass at iteration 70000: 0.5474225511099964
# Trapped probability mass at iteration 70100: 0.5474225511099964
# Trapped probability mass at iteration 70200: 0.5474225511099964
# Trapped probability mass at iteration 70300: 0.5474225511099964
# Trapped probability mass at iteration 70400: 0.5474225511099964
# Trapped probability mass at iteration 70500: 0.5474225511099964
# Trapped probability mass at iteration 70600: 0.5474225511099964
# Trapped probability mass at iteration 70700: 0.5474225511099964
# Trapped probability mass at iteration 70800: 0.5474225511099964
# Trapped probability mass at iteration 70900: 0.5474225511099964
# Trapped probability mass at iteration 71000: 0.5474225511099964
# Trapped probability mass at iteration 71100: 0.5474225511099964
# Trapped probability mass at iteration 71200: 0.5474225511099964
# Trapped probability mass at iteration 71300: 0.5474225511099964
# Trapped probability mass at iteration 71400: 0.5474225511099964
# Trapped probability mass at iteration 71500: 0.5474225511099964
# Trapped probability mass at iteration 71600: 0.5474225511099964
# Trapped probability mass at iteration 71700: 0.5474225511099964
# Trapped probability mass at iteration 71800: 0.5474225511099964
# Trapped probability mass at iteration 71900: 0.5474225511099964
# Trapped probability mass at iteration 72000: 0.5474225511099964
# Trapped probability mass at iteration 72100: 0.5474225511099964
# Trapped probability mass at iteration 72200: 0.5474225511099964
# Trapped probability mass at iteration 72300: 0.5474225511099964
# Trapped probability mass at iteration 72400: 0.5474225511099964
# Trapped probability mass at iteration 72500: 0.5474225511099964
# Trapped probability mass at iteration 72600: 0.5474225511099964
# Trapped probability mass at iteration 72700: 0.5474225511099964
# Trapped probability mass at iteration 72800: 0.5474225511099964
# Trapped probability mass at iteration 72900: 0.5474225511099964
# Trapped probability mass at iteration 73000: 0.5474225511099964
# Trapped probability mass at iteration 73100: 0.5474225511099964
# Trapped probability mass at iteration 73200: 0.5474225511099964
# Trapped probability mass at iteration 73300: 0.5474225511099964
# Trapped probability mass at iteration 73400: 0.5474225511099964
# Trapped probability mass at iteration 73500: 0.5474225511099964
# Trapped probability mass at iteration 73600: 0.5474225511099964
# Trapped probability mass at iteration 73700: 0.5474225511099964
# Trapped probability mass at iteration 73800: 0.5474225511099964
# Trapped probability mass at iteration 73900: 0.5474225511099964
# Trapped probability mass at iteration 74000: 0.5474225511099964
# Trapped probability mass at iteration 74100: 0.5474225511099964
# Trapped probability mass at iteration 74200: 0.5474225511099964
# Trapped probability mass at iteration 74300: 0.5474225511099964
# Trapped probability mass at iteration 74400: 0.5474225511099964
# Trapped probability mass at iteration 74500: 0.5474225511099964
# Trapped probability mass at iteration 74600: 0.5474225511099964
# Trapped probability mass at iteration 74700: 0.5474225511099964
# Trapped probability mass at iteration 74800: 0.5474225511099964
# Trapped probability mass at iteration 74900: 0.5474225511099964
# Trapped probability mass at iteration 75000: 0.5474225511099964
# ...
# Trapped probability mass at iteration 1764800: 0.5474225511099964
# Trapped probability mass at iteration 1764900: 0.5474225511099964
# Trapped probability mass at iteration 1765000: 0.5474225511099964
# Trapped probability mass at iteration 1765100: 0.5474225511099964
# Trapped probability mass at iteration 1765200: 0.5474225511099964
# Trapped probability mass at iteration 1765300: 0.5474225511099964
# Trapped probability mass at iteration 1765400: 0.5474225511099964
# Trapped probability mass at iteration 1765500: 0.5474225511099964
# Trapped probability mass at iteration 1765600: 0.5474225511099964
# Trapped probability mass at iteration 1765700: 0.5474225511099964
# Trapped probability mass at iteration 1765800: 0.5474225511099964
# Trapped probability mass at iteration 1765900: 0.5474225511099964
# Trapped probability mass at iteration 1766000: 0.5474225511099964
# Trapped probability mass at iteration 1766100: 0.5474225511099964
# Trapped probability mass at iteration 1766200: 0.5474225511099964
# Trapped probability mass at iteration 1766300: 0.5474225511099964
# Trapped probability mass at iteration 1766400: 0.5474225511099964
# Trapped probability mass at iteration 1766500: 0.5474225511099964
# Trapped probability mass at iteration 1766600: 0.5474225511099964
# Trapped probability mass at iteration 1766700: 0.5474225511099964
# Trapped probability mass at iteration 1766800: 0.5474225511099964
# Trapped probability mass at iteration 1766900: 0.5474225511099964
# Trapped probability mass at iteration 1767000: 0.5474225511099964
# Trapped probability mass at iteration 1767100: 0.5474225511099964
# Trapped probability mass at iteration 1767200: 0.5474225511099964
# Trapped probability mass at iteration 1767300: 0.5474225511099964
# Trapped probability mass at iteration 1767400: 0.5474225511099964
# Trapped probability mass at iteration 1767500: 0.5474225511099964
# Trapped probability mass at iteration 1767600: 0.5474225511099964
# Trapped probability mass at iteration 1767700: 0.5474225511099964
# Trapped probability mass at iteration 1767800: 0.5474225511099964
# Trapped probability mass at iteration 1767900: 0.5474225511099964
# Trapped probability mass at iteration 1768000: 0.5474225511099964
# Trapped probability mass at iteration 1768100: 0.5474225511099964
# Trapped probability mass at iteration 1768200: 0.5474225511099964
# Trapped probability mass at iteration 1768300: 0.5474225511099964
# Trapped probability mass at iteration 1768400: 0.5474225511099964
# Trapped probability mass at iteration 1768500: 0.5474225511099964
# Trapped probability mass at iteration 1768600: 0.5474225511099964
# Trapped probability mass at iteration 1768700: 0.5474225511099964
# Trapped probability mass at iteration 1768800: 0.5474225511099964
# Trapped probability mass at iteration 1768900: 0.5474225511099964
# Trapped probability mass at iteration 1769000: 0.5474225511099964
# Trapped probability mass at iteration 1769100: 0.5474225511099964
# Trapped probability mass at iteration 1769200: 0.5474225511099964
# Trapped probability mass at iteration 1769300: 0.5474225511099964
# Trapped probability mass at iteration 1769400: 0.5474225511099964
# Trapped probability mass at iteration 1769500: 0.5474225511099964
# Trapped probability mass at iteration 1769600: 0.5474225511099964
# Trapped probability mass at iteration 1769700: 0.5474225511099964
# Trapped probability mass at iteration 1769800: 0.5474225511099964
# Trapped probability mass at iteration 1769900: 0.5474225511099964
# Trapped probability mass at iteration 1770000: 0.5474225511099964
# Trapped probability mass at iteration 1770100: 0.5474225511099964
# Trapped probability mass at iteration 1770200: 0.5474225511099964
# Trapped probability mass at iteration 1770300: 0.5474225511099964
# Trapped probability mass at iteration 1770400: 0.5474225511099964
# Trapped probability mass at iteration 1770500: 0.5474225511099964
# Trapped probability mass at iteration 1770600: 0.5474225511099964
# Trapped probability mass at iteration 1770700: 0.5474225511099964
# Trapped probability mass at iteration 1770800: 0.5474225511099964
# Trapped probability mass at iteration 1770900: 0.5474225511099964
# Trapped probability mass at iteration 1771000: 0.5474225511099964
# Trapped probability mass at iteration 1771100: 0.5474225511099964
# Trapped probability mass at iteration 1771200: 0.5474225511099964
# Trapped probability mass at iteration 1771300: 0.5474225511099964
# Trapped probability mass at iteration 1771400: 0.5474225511099964
# Trapped probability mass at iteration 1771500: 0.5474225511099964
# Trapped probability mass at iteration 1771600: 0.5474225511099964
# Trapped probability mass at iteration 1771700: 0.5474225511099964
# Trapped probability mass at iteration 1771800: 0.5474225511099964
# Trapped probability mass at iteration 1771900: 0.5474225511099964
# Trapped probability mass at iteration 1772000: 0.5474225511099964
# Trapped probability mass at iteration 1772100: 0.5474225511099964
# Trapped probability mass at iteration 1772200: 0.5474225511099964
# Trapped probability mass at iteration 1772300: 0.5474225511099964
# Trapped probability mass at iteration 1772400: 0.5474225511099964
# Trapped probability mass at iteration 1772500: 0.5474225511099964
# Trapped probability mass at iteration 1772600: 0.5474225511099964
# Trapped probability mass at iteration 1772700: 0.5474225511099964
# Trapped probability mass at iteration 1772800: 0.5474225511099964
# Trapped probability mass at iteration 1772900: 0.5474225511099964
# Trapped probability mass at iteration 1773000: 0.5474225511099964
# Trapped probability mass at iteration 1773100: 0.5474225511099964
# Trapped probability mass at iteration 1773200: 0.5474225511099964
# Trapped probability mass at iteration 1773300: 0.5474225511099964
# Trapped probability mass at iteration 1773400: 0.5474225511099964
# Trapped probability mass at iteration 1773500: 0.5474225511099964
# Trapped probability mass at iteration 1773600: 0.5474225511099964
# Trapped probability mass at iteration 1773700: 0.5474225511099964
# Trapped probability mass at iteration 1773800: 0.5474225511099964
# Trapped probability mass at iteration 1773900: 0.5474225511099964
# Trapped probability mass at iteration 1774000: 0.5474225511099964
# Trapped probability mass at iteration 1774100: 0.5474225511099964
# Trapped probability mass at iteration 1774200: 0.5474225511099964
# Trapped probability mass at iteration 1774300: 0.5474225511099964
# Trapped probability mass at iteration 1774400: 0.5474225511099964
# Trapped probability mass at iteration 1774500: 0.5474225511099964
# Trapped probability mass at iteration 1774600: 0.5474225511099964
# Trapped probability mass at iteration 1774700: 0.5474225511099964
# Trapped probability mass at iteration 1774800: 0.5474225511099964
# Trapped probability mass at iteration 1774900: 0.5474225511099964
# Trapped probability mass at iteration 1775000: 0.5474225511099964
# Trapped probability mass at iteration 1775100: 0.5474225511099964
# Trapped probability mass at iteration 1775200: 0.5474225511099964
# Trapped probability mass at iteration 1775300: 0.5474225511099964
# Trapped probability mass at iteration 1775400: 0.5474225511099964
# Trapped probability mass at iteration 1775500: 0.5474225511099964
# Trapped probability mass at iteration 1775600: 0.5474225511099964
# Trapped probability mass at iteration 1775700: 0.5474225511099964
# Trapped probability mass at iteration 1775800: 0.5474225511099964
# Trapped probability mass at iteration 1775900: 0.5474225511099964
# Trapped probability mass at iteration 1776000: 0.5474225511099964
# Trapped probability mass at iteration 1776100: 0.5474225511099964
# Trapped probability mass at iteration 1776200: 0.5474225511099964
# Trapped probability mass at iteration 1776300: 0.5474225511099964
# Trapped probability mass at iteration 1776400: 0.5474225511099964
# Trapped probability mass at iteration 1776500: 0.5474225511099964
# Trapped probability mass at iteration 1776600: 0.5474225511099964
# Trapped probability mass at iteration 1776700: 0.5474225511099964
# Trapped probability mass at iteration 1776800: 0.5474225511099964
# Trapped probability mass at iteration 1776900: 0.5474225511099964
# Trapped probability mass at iteration 1777000: 0.5474225511099964
# Trapped probability mass at iteration 1777100: 0.5474225511099964
# Trapped probability mass at iteration 1777200: 0.5474225511099964
# Trapped probability mass at iteration 1777300: 0.5474225511099964
# Trapped probability mass at iteration 1777400: 0.5474225511099964
# Trapped probability mass at iteration 1777500: 0.5474225511099964
# Trapped probability mass at iteration 1777600: 0.5474225511099964
# Trapped probability mass at iteration 1777700: 0.5474225511099964
# Trapped probability mass at iteration 1777800: 0.5474225511099964
# Trapped probability mass at iteration 1777900: 0.5474225511099964
# Trapped probability mass at iteration 1778000: 0.5474225511099964
# Trapped probability mass at iteration 1778100: 0.5474225511099964
# Trapped probability mass at iteration 1778200: 0.5474225511099964
# Trapped probability mass at iteration 1778300: 0.5474225511099964
# Trapped probability mass at iteration 1778400: 0.5474225511099964
# Trapped probability mass at iteration 1778500: 0.5474225511099964
# Trapped probability mass at iteration 1778600: 0.5474225511099964
# Trapped probability mass at iteration 1778700: 0.5474225511099964
# Trapped probability mass at iteration 1778800: 0.5474225511099964
# Trapped probability mass at iteration 1778900: 0.5474225511099964
# Trapped probability mass at iteration 1779000: 0.5474225511099964
# Trapped probability mass at iteration 1779100: 0.5474225511099964
# Trapped probability mass at iteration 1779200: 0.5474225511099964
# Trapped probability mass at iteration 1779300: 0.5474225511099964
# Trapped probability mass at iteration 1779400: 0.5474225511099964
# Trapped probability mass at iteration 1779500: 0.5474225511099964
# Trapped probability mass at iteration 1779600: 0.5474225511099964
# Trapped probability mass at iteration 1779700: 0.5474225511099964
# Trapped probability mass at iteration 1779800: 0.5474225511099964
# Trapped probability mass at iteration 1779900: 0.5474225511099964
# Trapped probability mass at iteration 1780000: 0.5474225511099964
# Trapped probability mass at iteration 1780100: 0.5474225511099964
# Trapped probability mass at iteration 1780200: 0.5474225511099964
# Trapped probability mass at iteration 1780300: 0.5474225511099964
# Trapped probability mass at iteration 1780400: 0.5474225511099964
# Trapped probability mass at iteration 1780500: 0.5474225511099964
# Trapped probability mass at iteration 1780600: 0.5474225511099964
# Trapped probability mass at iteration 1780700: 0.5474225511099964
# Trapped probability mass at iteration 1780800: 0.5474225511099964
# Trapped probability mass at iteration 1780900: 0.5474225511099964
# Trapped probability mass at iteration 1781000: 0.5474225511099964
# Trapped probability mass at iteration 1781100: 0.5474225511099964
# Trapped probability mass at iteration 1781200: 0.5474225511099964
# Trapped probability mass at iteration 1781300: 0.5474225511099964
# Trapped probability mass at iteration 1781400: 0.5474225511099964
# Trapped probability mass at iteration 1781500: 0.5474225511099964
# Trapped probability mass at iteration 1781600: 0.5474225511099964
# Trapped probability mass at iteration 1781700: 0.5474225511099964
# Trapped probability mass at iteration 1781800: 0.5474225511099964
# Trapped probability mass at iteration 1781900: 0.5474225511099964
# Trapped probability mass at iteration 1782000: 0.5474225511099964
# Trapped probability mass at iteration 1782100: 0.5474225511099964
# Trapped probability mass at iteration 1782200: 0.5474225511099964
# Trapped probability mass at iteration 1782300: 0.5474225511099964
# Trapped probability mass at iteration 1782400: 0.5474225511099964
# Trapped probability mass at iteration 1782500: 0.5474225511099964
# Trapped probability mass at iteration 1782600: 0.5474225511099964
# Trapped probability mass at iteration 1782700: 0.5474225511099964
# Trapped probability mass at iteration 1782800: 0.5474225511099964
# Trapped probability mass at iteration 1782900: 0.5474225511099964
# Trapped probability mass at iteration 1783000: 0.5474225511099964
# Trapped probability mass at iteration 1783100: 0.5474225511099964
# Trapped probability mass at iteration 1783200: 0.5474225511099964
# Trapped probability mass at iteration 1783300: 0.5474225511099964
# Trapped probability mass at iteration 1783400: 0.5474225511099964
# Trapped probability mass at iteration 1783500: 0.5474225511099964
# Trapped probability mass at iteration 1783600: 0.5474225511099964
# Trapped probability mass at iteration 1783700: 0.5474225511099964
# Trapped probability mass at iteration 1783800: 0.5474225511099964
# Trapped probability mass at iteration 1783900: 0.5474225511099964
# Trapped probability mass at iteration 1784000: 0.5474225511099964
# Trapped probability mass at iteration 1784100: 0.5474225511099964
# Trapped probability mass at iteration 1784200: 0.5474225511099964
# Trapped probability mass at iteration 1784300: 0.5474225511099964
# Trapped probability mass at iteration 1784400: 0.5474225511099964
# Trapped probability mass at iteration 1784500: 0.5474225511099964
# Trapped probability mass at iteration 1784600: 0.5474225511099964
# Trapped probability mass at iteration 1784700: 0.5474225511099964
# Trapped probability mass at iteration 1784800: 0.5474225511099964
# Trapped probability mass at iteration 1784900: 0.5474225511099964
# Trapped probability mass at iteration 1785000: 0.5474225511099964
# Trapped probability mass at iteration 1785100: 0.5474225511099964
# Trapped probability mass at iteration 1785200: 0.5474225511099964
# Trapped probability mass at iteration 1785300: 0.5474225511099964
# Trapped probability mass at iteration 1785400: 0.5474225511099964
# Trapped probability mass at iteration 1785500: 0.5474225511099964
# Trapped probability mass at iteration 1785600: 0.5474225511099964
# Trapped probability mass at iteration 1785700: 0.5474225511099964
# Trapped probability mass at iteration 1785800: 0.5474225511099964
# Trapped probability mass at iteration 1785900: 0.5474225511099964
# Trapped probability mass at iteration 1786000: 0.5474225511099964
# Trapped probability mass at iteration 1786100: 0.5474225511099964
# Trapped probability mass at iteration 1786200: 0.5474225511099964
# Trapped probability mass at iteration 1786300: 0.5474225511099964
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Make graph of the cursive Pts
# ----> 3 cursive_Pts_random = get_cursive_Pts(A_random, P0, NUMBER_OF_SQUARES, 10e-6)
#       5 # Plot cursive Pts
#       7 plt.title('Cursive Pts')
#
# Cell In[23], line 29, in get_cursive_Pts(current_A, P0, number_of_sites, free_probability_treshhold_for_theory_calc)
#      26 trapped_prob_mass = sum(Cursive_Pts)
#      28 if iterations % delta_iterations_for_check == 0:
# ---> 29     print(f'Trapped probability mass at iteration {iterations}: {trapped_prob_mass}')
#      31 if 1 - trapped_prob_mass < free_probability_treshhold_for_theory_calc:
#      32     break
#
# File ~/miniconda3/envs/smart_walkers/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3038, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3036 if not data:
#    3037     return result
# -> 3038 execution_count = self.execution_count
#    3039 output_stream = None
#    3040 outputs_by_counter = self.history_manager.outputs
#
# File ~/miniconda3/envs/smart_walkers/lib/python3.13/site-packages/traitlets/traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     685     return self
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~/miniconda3/envs/smart_walkers/lib/python3.13/site-packages/traitlets/traitlets.py:629, in TraitType.get(self, obj, cls)
#     626     obj._trait_values[self.name] = value
#     627     return value
# --> 629 def get(self, obj: HasTraits, cls: type[t.Any] | None = None) -> G | None:
#     630     assert self.name is not None
#     631     try:
#
# KeyboardInterrupt:
